# %%
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import matplotlib.ft2font as ft
import matplotlib.font_manager as font_manager
mpl.rcParams['figure.dpi'] = 350
import matplotlib.ft2font as ft
import matplotlib.font_manager as font_manager
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
ccfpath = r'C:\Users\Martina\Google Drive\tide_induced_gw_level\spreadsheets\results_table'

# %%
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams.update({'font.size': 12}) 

w = pd.read_csv(r'C:\Users\Martina\Google Drive\tide_induced_gw_level\spreadsheets\results_table\allK.csv',  header=0)
fig, ax = plt.subplots(1, 1,  figsize=(18, 6))
ax.scatter(w['distance'], w['FFT2019'],color ='red',marker='o',s=10,edgecolors= 'red', label = 'FFT segments')
ax.scatter(w['distance'], w['FFT2020'],color ='red',marker='o',s=10, edgecolors= 'red')
ax.scatter(w['distance'], w['FFT_aver'],marker='o', s=60,edgecolors= 'red',facecolors='none',label = 'FFT average')
ax.scatter(w['distance'], w['12-hmf2018'],color ='blue',marker='D', s=10,label = '12-hmf segments')
ax.scatter(w['distance'], w['12-hmf2019'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2020'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2007'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2010'],color ='blue',marker='D',s=10)
ax.scatter(w['distance'], w['12-hmf_aver'],marker='D', s=60,edgecolors= 'blue',facecolors='none',label = '12-hmf average')
ax.set_ylim([0.0001, 10])
ax.set( yscale="log")
ax.axvline(x = 12,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 41,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 59,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 74,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 89,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 121,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 128,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 139,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 148,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 298,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 598,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 633,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 877,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.text(400, 14, 'Monitoring well',color='k', size=16, weight='bold')
ax.text(8, 12, 'NI',color='k', size=10, weight='bold')
ax.text(30, 6, 'PVP',color='k', size=10, weight='bold')
ax.text(48, 12, 'MBM',color='k', size=10, weight='bold')
ax.text(66, 6, 'IBP',color='k', size=10, weight='bold')
ax.text(80, 12, 'SWP',color='k', size=10, weight='bold')
ax.text(112, 6, 'FP',color='k', size=10, weight='bold')
ax.text(122, 12, 'NSP',color='k', size=10, weight='bold')
ax.text(130, 6, 'AFP',color='k', size=10, weight='bold')
ax.text(145, 4, 'CP',color='k', size=10, weight='bold')
ax.text(292, 12, 'LG',color='k', size=10, weight='bold')
ax.text(590, 12, 'FLP',color='k', size=10, weight='bold')
ax.text(620, 12, 'MBHS',color='k', size=10, weight='bold')
ax.text(860, 12, 'G-3549',color='k', size=10, weight='bold')
ax.set_ylabel("Hydraulic conductivity (m/s)")
ax.set_xlabel("Distance from the shore (m)")
#ax.set_title("Estimated hydraulic conductivity")
#ax.legend(loc='upper right')
box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='lower right')

# %%
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams.update({'font.size': 12}) 

w = pd.read_csv(r'C:\Users\Martina\Google Drive\tide_induced_gw_level\spreadsheets\results_table\allK.csv',  header=0)
fig, ax = plt.subplots(1, 1,  figsize=(18, 6))
ax.scatter(w['distance'], w['FFT2019'],color ='red',marker='o',s=10,edgecolors= 'red', label = 'FFT segments')
ax.scatter(w['distance'], w['FFT2020'],color ='red',marker='o',s=10, edgecolors= 'red')
ax.scatter(w['distance'], w['FFT_aver'],marker='o', s=60,edgecolors= 'red',facecolors='none',label = 'FFT average')
ax.scatter(w['distance'], w['12-hmf2018'],color ='blue',marker='D', s=10,label = '12-hmf segments')
ax.scatter(w['distance'], w['12-hmf2019'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2020'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2007'],color ='blue',marker='D', s=10)
ax.scatter(w['distance'], w['12-hmf2010'],color ='blue',marker='D',s=10)
ax.scatter(w['distance'], w['12-hmf_aver'],marker='D', s=60,edgecolors= 'blue',facecolors='none',label = '12-hmf average')
ax.set_ylim([0.0001, 10])
ax.set( yscale="log")
ax.set( xscale="log")
ax.axvline(x = 12,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 41,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 59,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 74,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 89,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 121,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 128,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 139,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 148,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 298,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 598,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 633,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.axvline(x = 877,linewidth=1,linestyle= '--', color= 'gray', alpha = 0.7)
ax.text(18, 14, 'Monitoring well',color='k', size=16, weight='bold')
ax.text(11, 12, 'NI',color='k', size=10, weight='bold')
ax.text(40, 6, 'PVP',color='k', size=10, weight='bold')
ax.text(56, 12, 'MBM',color='k', size=10, weight='bold')
ax.text(66, 6, 'IBP',color='k', size=10, weight='bold')
ax.text(80, 12, 'SWP',color='k', size=10, weight='bold')
ax.text(112, 6, 'FP',color='k', size=10, weight='bold')
ax.text(122, 12, 'NSP',color='k', size=10, weight='bold')
ax.text(130, 6, 'AFP',color='k', size=10, weight='bold')
ax.text(145, 4, 'CP',color='k', size=10, weight='bold')
ax.text(292, 12, 'LG',color='k', size=10, weight='bold')
ax.text(540, 12, 'FLP',color='k', size=10, weight='bold')
ax.text(620, 12, 'MBHS',color='k', size=10, weight='bold')
ax.text(860, 12, 'G-3549',color='k', size=10, weight='bold')
#ax.plot(xp,p1(xp),'b',lw=2)
ax.set_ylabel("Hydraulic conductivity (m/s)")
ax.set_xlabel("Distance from shore (m)")
#ax.set_title("Estimated hydraulic conductivity")
#ax.legend(loc='upper right')
box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='lower right')

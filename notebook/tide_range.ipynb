# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import matplotlib.ft2font as ft
import matplotlib.font_manager as font_manager
mpl.rcParams['figure.dpi'] = 350
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14

df = pd.read_csv(r'G:\My Drive\tide_induced_gw_level\spreadsheets\tide_range\tide_range.csv',  header=0, parse_dates=True, index_col='date')

# %%
fig, ax = plt.subplots(1, 1,  figsize=(12, 4))
ax.plot(df['Tide range (m)'],color ='blue',alpha=0.7, label = 'Virginia Key tide range')
ax.set_ylabel("Tide range (m)")
ax.set_xlabel("Date (year)")
ax.set_title("Tide range at Virginia Key tide station")
#ax.legend(loc='upper right')
# Out:
# Text(0.5, 1.0, 'Tide range at Virginia Key tide station')
